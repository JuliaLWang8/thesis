# %%
import pandas as pd
from datetime import datetime
import matplotlib.pyplot as plt
import numpy as np
from importlib import reload
import vrnngan2
vrnngan2 = reload(vrnngan2)
from vrnngan2 import VRNNGRUGAN, VRNNGRU
from tensorflow import keras
import tensorflow as tf

# %%
transactions = pd.read_csv('https://raw.githubusercontent.com/BigTuna08/Banksformer_ecml_2022/main/czech/banksformer/data/tr_by_acct_w_age.csv')

# %%
transactions.head()
# from 1995-03-24 to 1998-12-31
# Out:
#    Unnamed: 0  account_id    date    type                     operation  \
# 0      149432           1  950324  CREDIT                CREDIT IN CASH
# 1      157404           1  950413  CREDIT  COLLECTION FROM ANOTHER BANK
# 2      158832           1  950423  CREDIT                CREDIT IN CASH
# 3      162681           1  950430  CREDIT                           NaN
# 4      167083           1  950513  CREDIT  COLLECTION FROM ANOTHER BANK
#
#     amount  balance           k_symbol  client_id  age    datetime
# 0   1000.0   1000.0                NaN          1   29  1995-03-24
# 1   3679.0   4679.0                NaN          1   29  1995-04-13
# 2  12600.0  17279.0                NaN          1   29  1995-04-23
# 3     19.2  17298.2  INTEREST CREDITED          1   29  1995-04-30
# 4   3679.0  20977.2                NaN          1   29  1995-05-13

# %%
print(transactions.shape)
# Out:
# (1056320, 11)

# %%
transactions['datetime'] = pd.to_datetime(transactions['datetime'])
# latest_date = transactions['datetime'].min()
# transactions['datetime_num'] = transactions['datetime'].apply(lambda x: (x - latest_date).days)
# transactions.plot.scatter(x='datetime_num', y='amount', alpha=0.1)
transactions.plot.scatter(x='datetime', y='amount', alpha=0.1)
# Out:
# d:\coding\vae-gan-privacy\venv\lib\site-packages\pandas\plotting\_matplotlib\core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(
# <Axes: xlabel='datetime', ylabel='amount'>

# %%
filtered_transactions = transactions[transactions['account_id'] == 1]
filtered_transactions.plot.scatter(x='datetime', y='amount')
# Out:
# <Axes: xlabel='datetime', ylabel='amount'>

# %%
train = np.asarray(filtered_transactions[filtered_transactions['datetime'] < '1996-07-01']['amount'])
test = np.asarray(filtered_transactions[filtered_transactions['datetime'] >= '1996-07-01']['amount'])

# %%
# import numpy as np
# X_train = np.asarray(filtered_transactions[(filtered_transactions['datetime_num'] > 800) & (filtered_transactions['datetime_num'] < 1400)]['datetime_num'].values.reshape(-1, 1))
# y_train = np.asarray(filtered_transactions[(filtered_transactions['datetime_num'] > 800) & (filtered_transactions['datetime_num'] < 1400)]['amount'].values.reshape(-1, 1))

# X_test = np.asarray(filtered_transactions[filtered_transactions['datetime_num'] >= 1400]['datetime_num'].values.reshape(-1, 1))
# y_test = np.asarray(filtered_transactions[filtered_transactions['datetime_num'] >= 1400]['amount'].values.reshape(-1, 1))


# window = 200
# X_train = np.asarray([train[i:i+window] for i in range(len(train)-window - 1)]).reshape(-1, window, 1)
# Y_train = np.asarray([train[i:i+window] for i in range(1, len(train)-window)]).reshape(-1, window, 1)
# X_test = np.asarray([test[i:i+window] for i in range(len(test)-window-1)]).reshape(-1, window, 1)
# Y_test = np.asarray([test[i:i+window] for i in range(1, len(test)-window)]).reshape(-1, window, 1)

window=20
X_train = np.asarray([train[i:i+window] for i in range(len(train)-window - 1)])[:,:,np.newaxis]
Y_train = np.asarray([train[i:i+window] for i in range(1, len(train)-window)])[:,:,np.newaxis]
X_test = np.asarray([test[i:i+window] for i in range(len(test)-window-1)])[:,:,np.newaxis]
Y_test = np.asarray([test[i:i+window] for i in range(len(test)-window)])[:,:,np.newaxis]

X_train.shape
# Out:
# (57, 20, 1)

# %%
tf.keras.backend.clear_session()

timesteps = X_train.shape[1]
feature_space = X_train.shape[2]
latent_dim = 16
z_dim = 16

model = VRNNGRUGAN(feature_space, z_dim, latent_dim, timesteps, 0.4)
model.compile(keras.optimizers.Adam(learning_rate=0.0001), keras.optimizers.Adam(learning_rate=0.03))
model.fit(X_train, Y_train, batch_size= 16, epochs=100)
# Out:
# Epoch 1/100
# 4/4 [==============================] - 24s 14ms/step - total_loss: 105827328.0000 - loss: 106576992.0000 - kl: 0.0285 - discrim_loss: 1.9729 - discrim_loss_fake: 0.5121 - discrim_loss_real: 0.9572
# Epoch 2/100
# 4/4 [==============================] - 0s 16ms/step - total_loss: 104061880.0000 - loss: 103090932.8000 - kl: 0.0258 - discrim_loss: 1.9497 - discrim_loss_fake: 0.4756 - discrim_loss_real: 0.9958
# Epoch 3/100
# 4/4 [==============================] - 0s 16ms/step - total_loss: 113870752.0000 - loss: 99597046.4000 - kl: 0.0235 - discrim_loss: 1.9462 - discrim_loss_fake: 0.4950 - discrim_loss_real: 0.9582
# Epoch 4/100
# 4/4 [==============================] - 0s 16ms/step - total_loss: 105814576.0000 - loss: 106680966.4000 - kl: 0.0239 - discrim_loss: 1.9465 - discrim_loss_fake: 0.4281 - discrim_loss_real: 1.0910
# Epoch 5/100
# 4/4 [==============================] - 0s 16ms/step - total_loss: 105401160.0000 - loss: 104662368.0000 - kl: 0.0226 - discrim_loss: 1.9438 - discrim_loss_fake: 0.4713 - discrim_loss_real: 1.0005
# Epoch 6/100
# 4/4 [==============================] - 0s 16ms/step - total_loss: 106838920.0000 - loss: 106963859.2000 - kl: 0.0210 - discrim_loss: 1.9435 - discrim_loss_fake: 0.4820 - discrim_loss_real: 0.9801
# Epoch 7/100
# 4/4 [==============================] - 0s 19ms/step - total_loss: 102766800.0000 - loss: 112291144.0000 - kl: 0.0217 - discrim_loss: 1.9434 - discrim_loss_fake: 0.4469 - discrim_loss_real: 1.0494
# Epoch 8/100
# 4/4 [==============================] - 0s 18ms/step - total_loss: 104583024.0000 - loss: 106105446.4000 - kl: 0.0192 - discrim_loss: 1.9426 - discrim_loss_fake: 0.4585 - discrim_loss_real: 1.0257
# Epoch 9/100
# 4/4 [==============================] - 0s 16ms/step - total_loss: 107768880.0000 - loss: 103883920.0000 - kl: 0.0175 - discrim_loss: 1.9428 - discrim_loss_fake: 0.4745 - discrim_loss_real: 0.9940
# Epoch 10/100
# 4/4 [==============================] - 0s 16ms/step - total_loss: 108537528.0000 - loss: 104836217.6000 - kl: 0.0179 - discrim_loss: 1.9426 - discrim_loss_fake: 0.4568 - discrim_loss_real: 1.0288
# Epoch 11/100
# 4/4 [==============================] - 0s 16ms/step - total_loss: 103038168.0000 - loss: 105333099.2000 - kl: 0.0167 - discrim_loss: 1.9424 - discrim_loss_fake: 0.4572 - discrim_loss_real: 1.0282
# Epoch 12/100
# 4/4 [==============================] - 0s 18ms/step - total_loss: 109451248.0000 - loss: 101461139.2000 - kl: 0.0153 - discrim_loss: 1.9425 - discrim_loss_fake: 0.4685 - discrim_loss_real: 1.0054
# Epoch 13/100
# 4/4 [==============================] - 0s 19ms/step - total_loss: 104679352.0000 - loss: 103793356.8000 - kl: 0.0148 - discrim_loss: 1.9424 - discrim_loss_fake: 0.4598 - discrim_loss_real: 1.0227
# Epoch 14/100
# 4/4 [==============================] - 0s 16ms/step - total_loss: 106812136.0000 - loss: 105185748.8000 - kl: 0.0149 - discrim_loss: 1.9424 - discrim_loss_fake: 0.4590 - discrim_loss_real: 1.0244
# Epoch 15/100
# 4/4 [==============================] - 0s 17ms/step - total_loss: 107066560.0000 - loss: 106785358.4000 - kl: 0.0144 - discrim_loss: 1.9424 - discrim_loss_fake: 0.4654 - discrim_loss_real: 1.0116
# Epoch 16/100
# 4/4 [==============================] - 0s 16ms/step - total_loss: 104632784.0000 - loss: 110620107.2000 - kl: 0.0140 - discrim_loss: 1.9424 - discrim_loss_fake: 0.4603 - discrim_loss_real: 1.0218
# Epoch 17/100
# 4/4 [==============================] - 0s 15ms/step - total_loss: 105648528.0000 - loss: 102374017.6000 - kl: 0.0131 - discrim_loss: 1.9423 - discrim_loss_fake: 0.4608 - discrim_loss_real: 1.0208
# Epoch 18/100
# 4/4 [==============================] - 0s 16ms/step - total_loss: 104369808.0000 - loss: 104044368.0000 - kl: 0.0128 - discrim_loss: 1.9424 - discrim_loss_fake: 0.4636 - discrim_loss_real: 1.0151
# Epoch 19/100
# 4/4 [==============================] - 0s 16ms/step - total_loss: 107601976.0000 - loss: 103191523.2000 - kl: 0.0123 - discrim_loss: 1.9423 - discrim_loss_fake: 0.4604 - discrim_loss_real: 1.0215
# Epoch 20/100
# 4/4 [==============================] - 0s 16ms/step - total_loss: 106270856.0000 - loss: 109449574.4000 - kl: 0.0127 - discrim_loss: 1.9423 - discrim_loss_fake: 0.4619 - discrim_loss_real: 1.0185
# Epoch 21/100
# 4/4 [==============================] - 0s 16ms/step - total_loss: 102582056.0000 - loss: 107930905.6000 - kl: 0.0122 - discrim_loss: 1.9423 - discrim_loss_fake: 0.4624 - discrim_loss_real: 1.0176
# Epoch 22/100
# 4/4 [==============================] - 0s 16ms/step - total_loss: 103974720.0000 - loss: 106301259.2000 - kl: 0.0121 - discrim_loss: 1.9423 - discrim_loss_fake: 0.4609 - discrim_loss_real: 1.0206
# Epoch 23/100
# 4/4 [==============================] - 0s 16ms/step - total_loss: 104030648.0000 - loss: 111701113.6000 - kl: 0.0126 - discrim_loss: 1.9423 - discrim_loss_fake: 0.4623 - discrim_loss_real: 1.0177
# Epoch 24/100
# 4/4 [==============================] - 0s 16ms/step - total_loss: 104587552.0000 - loss: 113364344.0000 - kl: 0.0127 - discrim_loss: 1.9423 - discrim_loss_fake: 0.4616 - discrim_loss_real: 1.0192
# Epoch 25/100
# 4/4 [==============================] - 0s 16ms/step - total_loss: 105443032.0000 - loss: 113029905.6000 - kl: 0.0127 - discrim_loss: 1.9423 - discrim_loss_fake: 0.4616 - discrim_loss_real: 1.0192
# Epoch 26/100
# 4/4 [==============================] - 0s 15ms/step - total_loss: 105074528.0000 - loss: 108560449.6000 - kl: 0.0123 - discrim_loss: 1.9423 - discrim_loss_fake: 0.4621 - discrim_loss_real: 1.0182
# Epoch 27/100
# 4/4 [==============================] - 0s 16ms/step - total_loss: 106507304.0000 - loss: 101808048.0000 - kl: 0.0121 - discrim_loss: 1.9423 - discrim_loss_fake: 0.4614 - discrim_loss_real: 1.0195
# Epoch 28/100
# 4/4 [==============================] - 0s 16ms/step - total_loss: 103158240.0000 - loss: 107640776.0000 - kl: 0.0133 - discrim_loss: 1.9423 - discrim_loss_fake: 0.4619 - discrim_loss_real: 1.0185
# Epoch 29/100
# 4/4 [==============================] - 0s 15ms/step - total_loss: 107379008.0000 - loss: 106440843.2000 - kl: 0.0140 - discrim_loss: 1.9423 - discrim_loss_fake: 0.4617 - discrim_loss_real: 1.0190
# Epoch 30/100
# 4/4 [==============================] - 0s 16ms/step - total_loss: 108027712.0000 - loss: 106264014.4000 - kl: 0.0149 - discrim_loss: 1.9423 - discrim_loss_fake: 0.4617 - discrim_loss_real: 1.0190
# Epoch 31/100
# 4/4 [==============================] - 0s 16ms/step - total_loss: 106672616.0000 - loss: 103788204.8000 - kl: 0.0159 - discrim_loss: 1.9423 - discrim_loss_fake: 0.4618 - discrim_loss_real: 1.0187
# Epoch 32/100
# 4/4 [==============================] - 0s 16ms/step - total_loss: 108227824.0000 - loss: 105770137.6000 - kl: 0.0178 - discrim_loss: 1.9423 - discrim_loss_fake: 0.4616 - discrim_loss_real: 1.0191
# Epoch 33/100
# 4/4 [==============================] - 0s 16ms/step - total_loss: 109511568.0000 - loss: 101616492.8000 - kl: 0.0198 - discrim_loss: 1.9423 - discrim_loss_fake: 0.4618 - discrim_loss_real: 1.0187
# Epoch 34/100
# 4/4 [==============================] - 0s 16ms/step - total_loss: 102066080.0000 - loss: 106615507.2000 - kl: 0.0236 - discrim_loss: 1.9423 - discrim_loss_fake: 0.4617 - discrim_loss_real: 1.0190
# Epoch 35/100
# 4/4 [==============================] - 0s 16ms/step - total_loss: 102320664.0000 - loss: 112536627.2000 - kl: 0.0285 - discrim_loss: 1.9423 - discrim_loss_fake: 0.4618 - discrim_loss_real: 1.0188
# Epoch 36/100
# 4/4 [==============================] - 0s 15ms/step - total_loss: 103983040.0000 - loss: 101068516.8000 - kl: 0.0304 - discrim_loss: 1.9423 - discrim_loss_fake: 0.4617 - discrim_loss_real: 1.0189
# Epoch 37/100
# 4/4 [==============================] - 0s 16ms/step - total_loss: 105158224.0000 - loss: 108288656.0000 - kl: 0.0379 - discrim_loss: 1.9423 - discrim_loss_fake: 0.4617 - discrim_loss_real: 1.0189
# Epoch 38/100
# 4/4 [==============================] - 0s 16ms/step - total_loss: 107425576.0000 - loss: 107833963.2000 - kl: 0.0445 - discrim_loss: 1.9423 - discrim_loss_fake: 0.4618 - discrim_loss_real: 1.0188
# Epoch 39/100
# 4/4 [==============================] - 0s 16ms/step - total_loss: 109100688.0000 - loss: 101237636.8000 - kl: 0.0505 - discrim_loss: 1.9423 - discrim_loss_fake: 0.4617 - discrim_loss_real: 1.0189
# Epoch 40/100
# 4/4 [==============================] - 0s 17ms/step - total_loss: 107050104.0000 - loss: 100984097.6000 - kl: 0.0606 - discrim_loss: 1.9423 - discrim_loss_fake: 0.4618 - discrim_loss_real: 1.0188
# Epoch 41/100
# 4/4 [==============================] - 0s 17ms/step - total_loss: 108699664.0000 - loss: 106015700.8000 - kl: 0.0728 - discrim_loss: 1.9423 - discrim_loss_fake: 0.4617 - discrim_loss_real: 1.0189
# Epoch 42/100
# 4/4 [==============================] - 0s 16ms/step - total_loss: 103777848.0000 - loss: 111562641.6000 - kl: 0.0951 - discrim_loss: 1.9423 - discrim_loss_fake: 0.4617 - discrim_loss_real: 1.0188
# Epoch 43/100
# 4/4 [==============================] - 0s 20ms/step - total_loss: 105855112.0000 - loss: 103143667.2000 - kl: 0.1044 - discrim_loss: 1.9423 - discrim_loss_fake: 0.4617 - discrim_loss_real: 1.0189
# Epoch 44/100
# 4/4 [==============================] - 0s 17ms/step - total_loss: 105972968.0000 - loss: 104959126.4000 - kl: 0.1292 - discrim_loss: 1.9423 - discrim_loss_fake: 0.4617 - discrim_loss_real: 1.0189
# Epoch 45/100
# 4/4 [==============================] - 0s 16ms/step - total_loss: 104365648.0000 - loss: 106865985.6000 - kl: 0.1514 - discrim_loss: 1.9423 - discrim_loss_fake: 0.4617 - discrim_loss_real: 1.0189
# Epoch 46/100
# 4/4 [==============================] - 0s 16ms/step - total_loss: 108066920.0000 - loss: 102720793.6000 - kl: 0.1768 - discrim_loss: 1.9423 - discrim_loss_fake: 0.4617 - discrim_loss_real: 1.0189
# Epoch 47/100
# 4/4 [==============================] - 0s 16ms/step - total_loss: 103327032.0000 - loss: 103872068.8000 - kl: 0.2110 - discrim_loss: 1.9423 - discrim_loss_fake: 0.4617 - discrim_loss_real: 1.0189
# Epoch 48/100
# 4/4 [==============================] - 0s 16ms/step - total_loss: 104414144.0000 - loss: 108777438.4000 - kl: 0.2607 - discrim_loss: 1.9423 - discrim_loss_fake: 0.4617 - discrim_loss_real: 1.0189
# Epoch 49/100
# 4/4 [==============================] - 0s 16ms/step - total_loss: 107494312.0000 - loss: 100082972.8000 - kl: 0.2898 - discrim_loss: 1.9423 - discrim_loss_fake: 0.4617 - discrim_loss_real: 1.0189
# Epoch 50/100
# 4/4 [==============================] - 0s 16ms/step - total_loss: 110679112.0000 - loss: 97989825.6000 - kl: 0.3402 - discrim_loss: 1.9423 - discrim_loss_fake: 0.4617 - discrim_loss_real: 1.0189
# Epoch 51/100
# 4/4 [==============================] - 0s 16ms/step - total_loss: 103561888.0000 - loss: 102576417.6000 - kl: 0.4348 - discrim_loss: 1.9423 - discrim_loss_fake: 0.4617 - discrim_loss_real: 1.0189
# Epoch 52/100
# 4/4 [==============================] - 0s 16ms/step - total_loss: 105936560.0000 - loss: 109314732.8000 - kl: 0.5522 - discrim_loss: 1.9423 - discrim_loss_fake: 0.4617 - discrim_loss_real: 1.0189
# Epoch 53/100
# 4/4 [==============================] - 0s 16ms/step - total_loss: 106434192.0000 - loss: 106078660.8000 - kl: 0.6730 - discrim_loss: 1.9423 - discrim_loss_fake: 0.4617 - discrim_loss_real: 1.0189
# Epoch 54/100
# 4/4 [==============================] - 0s 16ms/step - total_loss: 104558800.0000 - loss: 106570280.0000 - kl: 0.8120 - discrim_loss: 1.9423 - discrim_loss_fake: 0.4617 - discrim_loss_real: 1.0189
# Epoch 55/100
# 4/4 [==============================] - 0s 19ms/step - total_loss: 106549912.0000 - loss: 101502057.6000 - kl: 0.9538 - discrim_loss: 1.9423 - discrim_loss_fake: 0.4617 - discrim_loss_real: 1.0189
# Epoch 56/100
# 4/4 [==============================] - 0s 18ms/step - total_loss: 102160368.0000 - loss: 107160134.4000 - kl: 1.2413 - discrim_loss: 1.9423 - discrim_loss_fake: 0.4617 - discrim_loss_real: 1.0189
# Epoch 57/100
# 4/4 [==============================] - 0s 16ms/step - total_loss: 106017384.0000 - loss: 107026300.8000 - kl: 1.4865 - discrim_loss: 1.9423 - discrim_loss_fake: 0.4617 - discrim_loss_real: 1.0189
# Epoch 58/100
# 4/4 [==============================] - 0s 16ms/step - total_loss: 104437096.0000 - loss: 106037843.2000 - kl: 1.8410 - discrim_loss: 1.9423 - discrim_loss_fake: 0.4617 - discrim_loss_real: 1.0189
# Epoch 59/100
# 4/4 [==============================] - 0s 16ms/step - total_loss: 105328184.0000 - loss: 103162824.0000 - kl: 2.3033 - discrim_loss: 1.9423 - discrim_loss_fake: 0.4617 - discrim_loss_real: 1.0189
# Epoch 60/100
# 4/4 [==============================] - 0s 16ms/step - total_loss: 102966224.0000 - loss: 106671636.8000 - kl: 2.8628 - discrim_loss: 1.9423 - discrim_loss_fake: 0.4617 - discrim_loss_real: 1.0189
# Epoch 61/100
# 4/4 [==============================] - 0s 16ms/step - total_loss: 108516568.0000 - loss: 99837404.8000 - kl: 3.3768 - discrim_loss: 1.9423 - discrim_loss_fake: 0.4617 - discrim_loss_real: 1.0189
# Epoch 62/100
# 4/4 [==============================] - 0s 17ms/step - total_loss: 107345904.0000 - loss: 107818307.2000 - kl: 4.3906 - discrim_loss: 1.9423 - discrim_loss_fake: 0.4617 - discrim_loss_real: 1.0189
# Epoch 63/100
# 4/4 [==============================] - 0s 17ms/step - total_loss: 106174168.0000 - loss: 102388107.2000 - kl: 5.2223 - discrim_loss: 1.9423 - discrim_loss_fake: 0.4617 - discrim_loss_real: 1.0189
# Epoch 64/100
# 4/4 [==============================] - 0s 17ms/step - total_loss: 106050192.0000 - loss: 109665328.0000 - kl: 6.7677 - discrim_loss: 1.9423 - discrim_loss_fake: 0.4617 - discrim_loss_real: 1.0189
# Epoch 65/100
# 4/4 [==============================] - 0s 17ms/step - total_loss: 104599608.0000 - loss: 112060972.8000 - kl: 8.5601 - discrim_loss: 1.9423 - discrim_loss_fake: 0.4617 - discrim_loss_real: 1.0189
# Epoch 66/100
# 4/4 [==============================] - 0s 16ms/step - total_loss: 105425056.0000 - loss: 105923500.8000 - kl: 9.9619 - discrim_loss: 1.9423 - discrim_loss_fake: 0.4617 - discrim_loss_real: 1.0189
# Epoch 67/100
# 4/4 [==============================] - 0s 17ms/step - total_loss: 104783792.0000 - loss: 107196505.6000 - kl: 12.4795 - discrim_loss: 1.9423 - discrim_loss_fake: 0.4617 - discrim_loss_real: 1.0189
# Epoch 68/100
# 4/4 [==============================] - 0s 18ms/step - total_loss: 109444464.0000 - loss: 109400520.0000 - kl: 16.3939 - discrim_loss: 1.9423 - discrim_loss_fake: 0.4617 - discrim_loss_real: 1.0189
# Epoch 69/100
# 4/4 [==============================] - 0s 17ms/step - total_loss: 106832392.0000 - loss: 99330136.0000 - kl: 19.0126 - discrim_loss: 1.9423 - discrim_loss_fake: 0.4617 - discrim_loss_real: 1.0189
# Epoch 70/100
# 4/4 [==============================] - 0s 16ms/step - total_loss: 105369992.0000 - loss: 103933737.6000 - kl: 23.9477 - discrim_loss: 1.9423 - discrim_loss_fake: 0.4617 - discrim_loss_real: 1.0189
# Epoch 71/100
# 4/4 [==============================] - 0s 17ms/step - total_loss: 108084328.0000 - loss: 104522516.8000 - kl: 29.4792 - discrim_loss: 1.9423 - discrim_loss_fake: 0.4617 - discrim_loss_real: 1.0189
# Epoch 72/100
# 4/4 [==============================] - 0s 17ms/step - total_loss: 106921096.0000 - loss: 106754337.6000 - kl: 37.8855 - discrim_loss: 1.9423 - discrim_loss_fake: 0.4617 - discrim_loss_real: 1.0189
# Epoch 73/100
# 4/4 [==============================] - 0s 17ms/step - total_loss: 105572264.0000 - loss: 104516283.2000 - kl: 46.4473 - discrim_loss: 1.9423 - discrim_loss_fake: 0.4617 - discrim_loss_real: 1.0189
# Epoch 74/100
# 4/4 [==============================] - 0s 18ms/step - total_loss: 107915824.0000 - loss: 104923286.4000 - kl: 56.2354 - discrim_loss: 1.9423 - discrim_loss_fake: 0.4617 - discrim_loss_real: 1.0189
# Epoch 75/100
# 4/4 [==============================] - 0s 18ms/step - total_loss: 105181816.0000 - loss: 104884288.0000 - kl: 71.9549 - discrim_loss: 1.9423 - discrim_loss_fake: 0.4617 - discrim_loss_real: 1.0189
# Epoch 76/100
# 4/4 [==============================] - 0s 18ms/step - total_loss: 102648088.0000 - loss: 111886193.6000 - kl: 93.9760 - discrim_loss: 1.9423 - discrim_loss_fake: 0.4617 - discrim_loss_real: 1.0189
# Epoch 77/100
# 4/4 [==============================] - 0s 18ms/step - total_loss: 111539808.0000 - loss: 103545673.6000 - kl: 109.0873 - discrim_loss: 1.9423 - discrim_loss_fake: 0.4617 - discrim_loss_real: 1.0189
# Epoch 78/100
# 4/4 [==============================] - 0s 16ms/step - total_loss: 109171440.0000 - loss: 100011347.2000 - kl: 133.9027 - discrim_loss: 1.9423 - discrim_loss_fake: 0.4617 - discrim_loss_real: 1.0189
# Epoch 79/100
# 4/4 [==============================] - 0s 17ms/step - total_loss: 107848464.0000 - loss: 100763844.8000 - kl: 164.3240 - discrim_loss: 1.9423 - discrim_loss_fake: 0.4617 - discrim_loss_real: 1.0189
# Epoch 80/100
# 4/4 [==============================] - 0s 19ms/step - total_loss: 111752000.0000 - loss: 101007158.4000 - kl: 203.0688 - discrim_loss: 1.9423 - discrim_loss_fake: 0.4617 - discrim_loss_real: 1.0189
# Epoch 81/100
# 4/4 [==============================] - 0s 18ms/step - total_loss: 106868496.0000 - loss: 106966803.2000 - kl: 249.3018 - discrim_loss: 1.9423 - discrim_loss_fake: 0.4617 - discrim_loss_real: 1.0189
# Epoch 82/100
# 4/4 [==============================] - 0s 17ms/step - total_loss: 107020120.0000 - loss: 108929092.8000 - kl: 301.4221 - discrim_loss: 1.9423 - discrim_loss_fake: 0.4617 - discrim_loss_real: 1.0189
# Epoch 83/100
# 4/4 [==============================] - 0s 16ms/step - total_loss: 108743280.0000 - loss: 107861099.2000 - kl: 348.8919 - discrim_loss: 1.9423 - discrim_loss_fake: 0.4617 - discrim_loss_real: 1.0189
# Epoch 84/100
# 4/4 [==============================] - 0s 17ms/step - total_loss: 102702416.0000 - loss: 107254968.0000 - kl: 412.5089 - discrim_loss: 1.9423 - discrim_loss_fake: 0.4617 - discrim_loss_real: 1.0189
# Epoch 85/100
# 4/4 [==============================] - 0s 16ms/step - total_loss: 104885984.0000 - loss: 104261798.4000 - kl: 466.3888 - discrim_loss: 1.9423 - discrim_loss_fake: 0.4617 - discrim_loss_real: 1.0189
# Epoch 86/100
# 4/4 [==============================] - 0s 16ms/step - total_loss: 105308960.0000 - loss: 104346633.6000 - kl: 538.2507 - discrim_loss: 1.9423 - discrim_loss_fake: 0.4617 - discrim_loss_real: 1.0189
# Epoch 87/100
# 4/4 [==============================] - 0s 16ms/step - total_loss: 108327552.0000 - loss: 100524880.0000 - kl: 582.8471 - discrim_loss: 1.9423 - discrim_loss_fake: 0.4617 - discrim_loss_real: 1.0189
# Epoch 88/100
# 4/4 [==============================] - 0s 16ms/step - total_loss: 105120528.0000 - loss: 107582072.0000 - kl: 667.7098 - discrim_loss: 1.9423 - discrim_loss_fake: 0.4617 - discrim_loss_real: 1.0189
# Epoch 89/100
# 4/4 [==============================] - 0s 16ms/step - total_loss: 106670584.0000 - loss: 105074702.4000 - kl: 728.0368 - discrim_loss: 1.9423 - discrim_loss_fake: 0.4617 - discrim_loss_real: 1.0189
# Epoch 90/100
# 4/4 [==============================] - 0s 16ms/step - total_loss: 107414048.0000 - loss: 104101374.4000 - kl: 793.0429 - discrim_loss: 1.9423 - discrim_loss_fake: 0.4617 - discrim_loss_real: 1.0189
# Epoch 91/100
# 4/4 [==============================] - 0s 16ms/step - total_loss: 103824264.0000 - loss: 106911140.8000 - kl: 870.7486 - discrim_loss: 1.9423 - discrim_loss_fake: 0.4617 - discrim_loss_real: 1.0189
# Epoch 92/100
# 4/4 [==============================] - 0s 17ms/step - total_loss: 105076416.0000 - loss: 110717337.6000 - kl: 948.5498 - discrim_loss: 1.9423 - discrim_loss_fake: 0.4617 - discrim_loss_real: 1.0189
# Epoch 93/100
# 4/4 [==============================] - 0s 16ms/step - total_loss: 107682968.0000 - loss: 103923830.4000 - kl: 1003.9707 - discrim_loss: 1.9423 - discrim_loss_fake: 0.4617 - discrim_loss_real: 1.0189
# Epoch 94/100
# 4/4 [==============================] - 0s 17ms/step - total_loss: 107541032.0000 - loss: 102521561.6000 - kl: 1077.5275 - discrim_loss: 1.9423 - discrim_loss_fake: 0.4617 - discrim_loss_real: 1.0189
# Epoch 95/100
# 4/4 [==============================] - 0s 16ms/step - total_loss: 104322120.0000 - loss: 107268779.2000 - kl: 1165.5445 - discrim_loss: 1.9423 - discrim_loss_fake: 0.4617 - discrim_loss_real: 1.0189
# Epoch 96/100
# 4/4 [==============================] - 0s 15ms/step - total_loss: 104574560.0000 - loss: 107001665.6000 - kl: 1259.5473 - discrim_loss: 1.9423 - discrim_loss_fake: 0.4617 - discrim_loss_real: 1.0189
# Epoch 97/100
# 4/4 [==============================] - 0s 16ms/step - total_loss: 104329896.0000 - loss: 100391563.2000 - kl: 1330.9313 - discrim_loss: 1.9423 - discrim_loss_fake: 0.4617 - discrim_loss_real: 1.0189
# Epoch 98/100
# 4/4 [==============================] - 0s 16ms/step - total_loss: 108163616.0000 - loss: 102630587.2000 - kl: 1432.0004 - discrim_loss: 1.9423 - discrim_loss_fake: 0.4617 - discrim_loss_real: 1.0189
# Epoch 99/100
# 4/4 [==============================] - 0s 15ms/step - total_loss: 105853920.0000 - loss: 104124953.6000 - kl: 1549.3654 - discrim_loss: 1.9423 - discrim_loss_fake: 0.4617 - discrim_loss_real: 1.0189
# Epoch 100/100
# 4/4 [==============================] - 0s 16ms/step - total_loss: 106989264.0000 - loss: 100383200.0000 - kl: 1659.9071 - discrim_loss: 1.9423 - discrim_loss_fake: 0.4617 - discrim_loss_real: 1.0189

# %%
outputs, z, q_mu, p_mu, q_logvar, p_logvar, output_mean, output_logvar, states = model.predict(X_train[0:300])
plt.scatter(range(len(outputs)), outputs[:, -1, :])
plt.xlabel('Sample Index')
plt.ylabel('Output')
plt.show()
# Out:
# 2/2 [==============================] - 0s 5ms/step

# %%
outputs, z, q_mu, p_mu, q_logvar, p_logvar, output_mean, output_logvar,_ = model.predict(X_test)
# Out:
# 5/5 [==============================] - 0s 3ms/step

# %%
plt.scatter(range(len(output_mean[:,-1,:])), output_mean[:,-1,:], label='predicted')
